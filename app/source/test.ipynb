# %%
import os
import io
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import plotly.express as px
import streamlit as st
import plotly.graph_objects as go
from sklearn.metrics import classification_report, confusion_matrix, roc_curve, auc
import seaborn as sns
from physical_prep import *

root = '../../dataset'

# %%
df_physical_raw, df_physical = physical_prep(root)
del df_physical_raw

# %%
df_network_downsampled = pd.read_csv(os.path.join(root, "Network datatset/csv/network_downsampled.csv"))
# Out:
# C:\Users\elmah\AppData\Local\Temp\ipykernel_28620\3947355646.py:1: DtypeWarning: Columns (11) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_network_downsampled = pd.read_csv(os.path.join(root, "Network datatset/csv/network_downsampled.csv"))

# %%
df_network_downsampled.head()
# Out:
#                          Time              mac_s              mac_d  \
# 0  2021-04-09 11:30:52.762468  e6:3f:ac:c9:a8:8c  74:46:a0:bd:a7:1b
# 1  2021-04-09 11:30:52.832624  0a:fe:ec:47:74:fb  74:46:a0:bd:a7:1b
# 2  2021-04-09 11:30:52.878637  fa:00:bc:90:d7:fa  74:46:a0:bd:a7:1b
# 3  2021-04-09 11:30:53.005366  00:80:f4:03:fb:12  74:46:a0:bd:a7:1b
# 4  2021-04-09 11:30:53.018780  e6:3f:ac:c9:a8:8c  74:46:a0:bd:a7:1b
#
#            ip_s         ip_d  sport    dport   proto    flags  size  \
# 0  84.3.251.101  84.3.251.20  502.0  61515.0  Modbus  11000.0    64
# 1  84.3.251.102  84.3.251.20  502.0  61517.0  Modbus  11000.0    65
# 2  84.3.251.103  84.3.251.20  502.0  61516.0  Modbus  11000.0    65
# 3   84.3.251.18  84.3.251.20  502.0  61514.0  Modbus  11000.0    65
# 4  84.3.251.101  84.3.251.20  502.0  61515.0  Modbus  11000.0    65
#
#                          modbus_fn n_pkt_src  n_pkt_dst  modbus_response  \
# ...

# %%
df_network_downsampled['Time'] = pd.to_datetime(df_network_downsampled['Time'], format='%Y-%m-%d %H:%M:%S.%f')

# %%
df_network_downsampled.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 120156 entries, 0 to 120155
# Data columns (total 18 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   Time                120156 non-null  datetime64[ns]
#  1   mac_s               120156 non-null  object
#  2   mac_d               120156 non-null  object
#  3   ip_s                120156 non-null  object
#  4   ip_d                120156 non-null  object
#  5   sport               120156 non-null  float64
#  6   dport               120156 non-null  float64
#  7   proto               120156 non-null  object
#  8   flags               120156 non-null  float64
#  9   size                120156 non-null  int64
#  10  modbus_fn           120156 non-null  object
#  11  n_pkt_src           120156 non-null  object
#  12  n_pkt_dst           120156 non-null  float64
#  13  modbus_response     120156 non-null  int64
#  14  Label_n             120156 non-null  int64
# ...
